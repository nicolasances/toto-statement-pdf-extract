# %% [markdown]
# # Experiments on PDF data extraction

# %%
import pdfquery as pq
import pandas as pd
import xml.etree.ElementTree as ET
from pprint import pprint
import re
import nltk
from nltk.tokenize import RegexpTokenizer
nltk.download('punkt')
# Out:
# [nltk_data] Error loading punkt: <urlopen error [SSL:
# [nltk_data]     CERTIFICATE_VERIFY_FAILED] certificate verify failed:
# [nltk_data]     unable to get local issuer certificate (_ssl.c:997)>
# False

# %%
pdf = pq.PDFQuery("kud.pdf")
pdf.load()

pdf.tree.write('kud.xml', pretty_print=True)
pdf

# %%
def extract_lines(xmlFilename): 
    '''Extract all lines of text present in the XML (representing a PDF)
    
    Parameters: 
    xmlFilename (string): the file name of the xml to load. The XML is the PDF converted into XML.

    Returns: 
    dict: a dictionnary where the key is the identifier (page, line) (e.g. P1L670.11). Each element is a list of tokens belonging on the same line and page
        Example of keys:
        P1L503.007: ['Indestående ', 'Indsat ', 'Bogført ', 'Rente- ']
        P1L492.207: ['Gæld ', 'Hævet ', 'dato ', 'dato ']
        P1L468.447: ['494,42 - ', '3.291,68 ', '+ ', 'Gjensidige Forsikring, D ', '03.10 ', '03.10 ']

    '''

    tree = ET.parse(pdfFileName)
    root = tree.getroot()

    lines = {}

    pages = root.findall(".//LTPage")

    for page in pages: 
        page_num = int(page.get("pageid"))
        
        for line in page.findall(".//LTTextLineHorizontal"):
            y0 = float(line.get("y0"))
            index = "P" + str(page_num) + "L" + str(y0)

            text_element = line.text or line.find(".//LTTextBoxHorizontal").text

            if index in lines: 
                lines[index].append(text_element)
            else: 
                lines[index] = [text_element]

    return lines;

# %%
number_pattern = re.compile(r'^(\d{1,3}(?:\.\d{3})*(?:,\d{2})?)\s?([+-]?)$')

def clean_numbers(line): 
    '''Cleans the numbers contained in a given line.
    Cleaning up numbers means moving from '494,42 - ' to a float -494.42

    Parameters: 
    line (list): the list of tokens of the line

    Returns: 
    list: the cleaned line
    '''
    clean_line = []

    for token in line: 

        match = number_pattern.match(token.strip())

        if match:
            numeric_part, sign = match.groups()
            numeric_part = numeric_part.replace('.', '').replace(',', '.')  # Replace comma with period for decimal part
            number = float(numeric_part)
            if sign == '-':
                number = -number
            
            clean_line.append(number)
        else: 
            clean_line.append(token)

    return clean_line

# %%
useless_tokens_pattern = re.compile(r'^\s*\+\s*$')

def remove_useless_tokens(line):
    '''Removes tokens that are not needed.
    That is, for example, tokens ' +'
    Remove duplicate tokens

    Parameters: 
    line (list): the line as a list of tokens

    Returns:
    list: the clean line
    '''
    clean_line = []

    for token in line: 

        if isinstance(token, (int, float)): 
            clean_line.append(token)
            continue
        
        match = useless_tokens_pattern.match(token)

        if not match: 
            clean_line.append(token)


    return clean_line

# %%
def clean_date(line): 
    '''Cleans the date

    Parameters: 
    line (list): the line as a list of tokens

    Returns:
    list: the clean line
    '''
    clean_line = []

    for token in line: 

        if isinstance(token, (int, float)): 
            clean_line.append(token)
            continue

        clean_line.append(token.strip())
    
    return clean_line

# %%
tokenizer = RegexpTokenizer(r'\w+')
date_pattern = re.compile(r'\d{2}\.\d{2}\s*$')

def clean_text(line): 
    '''Cleans the text, only keeping words

    Parameters: 
    line (list): the line as a list of tokens

    Returns:
    list: the clean line
    '''
    clean_line = []

    for token in line: 

        if isinstance(token, (int, float)): 
            clean_line.append(token)
            continue

        if date_pattern.match(token):
            clean_line.append(token)
            continue

        text_tokens = tokenizer.tokenize(token)
        clean_text = ' '.join(text_tokens)

        clean_line.append(clean_text)
    
    return clean_line

# %%
def clean_lines(lines): 
    '''Takes the lines and cleans up the numbers and the text
    Cleaning up numbers means moving from '494,42 - ' to a float -494.42
    Cleans up dates (e.g. trims)
    '''

    pattern = re.compile(r'^(\d{1,3}(?:\.\d{3})*(?:,\d{2})?)\s?([+-]?)$')

    for key in lines.keys():

        # Clean the numbers
        lines[key] = clean_numbers(lines[key])

        # Remove useless tokens
        lines[key] = remove_useless_tokens(lines[key])

        # Cleans dates
        lines[key] = clean_date(lines[key])

        # Cleans the text description
        lines[key] = clean_text(lines[key])

    return lines

# %%
def filter_lines(lines):
    '''Filter the lines, keeping only the ones corresponding to payments
    
    Parameters: 
    lines (dict): the dictionnary of lines

    Returns: 
    dict: the updated dictionnary
    '''
    clean_lines = {}    

    for key, line in lines.items(): 

        # Count how many numbers this line contains. 
        # If the line contains >= 2 numbers, then it's a valid line, to keep
        num_numbers = sum(isinstance(item, (int, float)) for item in line)

        if num_numbers >= 2: 
            clean_lines[key] = line
    
    return clean_lines

# %%
def keep_tokens(lines): 
    '''Filter the tokens, keeping only the ones that are needed
    Removes the saldo
    Removes duplicate dates
    
    Parameters: 
    lines (dict): the dictionnary of lines

    Returns: 
    dict: the updated dictionnary
    '''
    clean_lines = {}    

    for key, line in lines.items(): 

        smallest_number = 10**20
        clean_line = []

        for token in line: 
            
            if isinstance(token, (int, float)): 
                if token < smallest_number: 
                    smallest_number = token
                continue
            
            # Check that the token is not already in the list (eliminate duplicates)
            if not token in clean_line: 
                clean_line.append(token)
        
        clean_line.append(smallest_number)

        clean_lines[key] = clean_line
    
    return clean_lines

# %%
# Extract lines
lines = extract_lines("kud.xml")

# Clean up lines
lines = clean_lines(lines)

# Filter lines
lines = filter_lines(lines)

# Remove tokens that are not needed
lines = keep_tokens(lines)

for line_key, line in lines.items(): 
    print(f"{line_key}: {line}")
# Out:
# P1L468.447: ['Gjensidige Forsikring D', '03.10', -494.42]
# P1L457.887: ['HK Handels og Kontorf', '03.10', -517.0]
# P1L447.327: ['Krogsgaard Finans', '03.10', -2474.0]
# P1L437.007: ['SuperB Solrød 38962', '03.10', -661.85]
# P1L426.447: ['SuperB Solrød 38965', '03.10', -4.95]
# P1L415.887: ['Q8 Service 8042 96109', '03.10', -620.44]
# P1L405.327: ['Maxi Zoo Gentofte 31308', '03.10', -198.95]
# P1L395.007: ['McDonalds Solroed rest', '04.10', -294.0]
# P1L311.007: ['Google CLOUD LPWQM6 Milan', '04.10', -164.01]
# P1L227.007: ['SuperB Solrød 06761', '04.10', -162.4]
# P1L216.447: ['MobilePay Caroline Boje', '06.10', -328.0]
# P1L205.887: ['7 Eleven B477 48210', '06.10', -81.0]
# P1L195.327: ['SECURITAS A S', '07.10', -210.0]
# P1L174.447: ['Fisketorvet Føtex 20767', '10.10', -868.6]
# P1L163.887: ['Fisketorvet Føtex 21631', '10.10', -599.65]
# P1L153.327: ['P huset Gl Mønt 48275', '10.10', -425.0]
# P1L143.007: ['PAYPAL EASYPARK AS 35314369001', '11.10', -45.71]
# P2L550.047: ['McDonalds Solroed rest', '11.10', -245.0]
# P2L466.047: ['SuperB Solrød 45871', '11.10', -355.95]
# P2L455.487: ['SuitSupply Copenhagen', '12.10', -3249.0]
# P2L382.047: ['4011320147', '13.10', -306589.32]
# P2L371.487: ['SuperB Solrød 47519', '13.10', -224.4]
# P2L360.927: ['SuperB Solrød 50290', '17.10', -631.7]
# P2L350.607: ['McDonalds Solroed rest', '18.10', -272.0]
# P2L266.607: ['PAYPAL UDEMY 35314369001', '18.10', -117.09]
# P2L192.927: ['Børne og Ungeydelse', '20.10', 2327.0]
# P2L108.927: ['24.10', 'SuperB Solrød 53410', -164.9]
# P2L98.607: ['24.10', 'MobilePay Caroline Boje', -599.75]
# P3L570.927: ['B Skat 20 10 2022', '25.10', -1069.0]
# P3L528.927: ['Lønoverførsel', '26.10', 45708.31]
# P3L476.607: ['McDonalds Solroed rest', '26.10', -289.0]
# P3L392.607: ['PAYPAL ADOBESYSTEM 35314369001', '26.10', -95.21]
# P3L308.607: ['SuperB Solrød 56531', '26.10', -906.7]
# P3L298.047: ['Q8 Service 8042 14485', '27.10', -648.17]
# P3L287.487: ['MobilePay Mette Bigom Ryom Herold', '28.10', -100.0]
# P3L276.927: ['Transfer to budget', '31.10', -7300.0]
# P3L266.607: ['Gjensidige Forsikring D', '01.11', -494.42]
# P3L256.047: ['Krogsgaard Finans', '01.11', -2474.0]
# P3L245.487: ['HK Handels og Kontorf', '01.11', -517.0]
# P3L234.927: ['APPLE COM BILL ITUNES COM', '01.11', -45.0]
# P3L161.487: ['KLARNA KLARNA STOCKHOLM', '01.11', -598.0]
# P4L570.927: ['McDonalds Solroed rest', '01.11', -266.0]
# P4L486.927: ['MobilePay Collection for Nanna', '01.11', -50.0]
# P4L476.607: ['Maxi Zoo Gentofte 37145', '01.11', -304.9]
# P4L466.047: ['SuperB Solrød 60999', '01.11', -189.1]
# P4L455.487: ['Kim Q Hair design 18619', '02.11', -349.0]
# P4L444.927: ['Google CLOUD 84w88T Milan', '03.11', -189.69]
# P4L360.927: ['MobilePay Pernille K Weeke', '03.11', -50.0]
# P4L350.607: ['ZARA FISKETORVERT 67494', '03.11', -522.0]
# P4L340.047: ['Fisketorvet Føtex 98870', '04.11', -559.42]
# P4L329.487: ['MobilePay Caroline Boje', '06.11', -328.0]
# P4L318.927: ['MobilePay Caroline Boje', '06.11', -62.0]
# P4L308.607: ['SuperB Solrød 64247', '07.11', -600.9]
# P4L298.047: ['Q8 Service 8042 22293', '07.11', -67.9]
# P4L287.487: ['SuperB Solrød 64932', '07.11', -51.95]
# P4L276.927: ['McDonalds Solroed rest', '08.11', -250.0]
# P4L192.927: ['4180 APCOA PARKING AS', '08.11', -30.0]
# P4L108.927: ['Bigbio Nordhavn 72869', '09.11', -149.0]
# P4L98.607: ['SuperB Solrød 67854', '10.11', -659.25]
# P5L570.927: ['PAYPAL EASYPARK AS 35314369001', '14.11', -29.2]
# P5L486.927: ['SuperB Solrød 70914', '14.11', -657.05]
# P5L476.607: ['McDonalds Solroed rest', '15.11', -256.0]
# P5L392.607: ['VDK DKK 917 58', '15.11', 917.58]
# P5L318.927: ['AMZN Mktp DE AMAZON DE', '16.11', -712.62]
# P5L245.487: ['Q8 Service 8042 30657', '17.11', -619.63]
# P5L234.927: ['Coffee Industri Sw 00405', '17.11', -154.0]
# P5L224.607: ['Juventus Pizza 92377', '17.11', -110.0]
# P5L214.047: ['4061 APCOA PARKING AS KOBENHAVN', '18.11', -280.0]
# P5L130.047: ['PAYPAL EASYPARK AS 35314369001', '21.11', -74.31]
# P6L550.047: ['SuperB Solrød 74861', '21.11', -369.25]
# P6L539.487: ['Solar panel inverter', '21.11', -11234.63]
# P6L508.047: ['PAYPAL EASYPARK AS 35314369001', '22.11', -33.35]
# P6L424.047: ['McDonalds Solroed rest', '22.11', -239.0]
# P6L340.047: ['SKATTEFORVALTNINGEN', '22.11', -1879.0]
# P6L308.607: ['SuperB Solrød 77745', '23.11', -342.05]
# P6L298.047: ['SuperB Solrød 26013', '23.11', -45.0]
# P6L287.487: ['MobilePay Caroline Boje', '24.11', -599.75]
# P6L276.927: ['Lønoverførsel', '25.11', 45708.31]
# P6L224.607: ['PAYPAL ADOBESYSTEM 35314369001', '25.11', -95.19]
# P6L140.607: ['SuperB Solrød 79946', '28.11', -912.45]
# P6L130.047: ['JOE THE JUICE A S Kastrup', '29.11', -59.0]
# P7L550.047: ['McDonalds Solroed rest', '29.11', -243.0]
# P7L466.047: ['Transfer to budget', '30.11', -7300.0]
# P7L455.487: ['APPLE COM BILL ITUNES COM', '30.11', -45.0]
# P7L382.047: ['Krogsgaard Finans', '01.12', -2474.0]
# P7L371.487: ['HK Handels og Kontorf', '01.12', -517.0]
# P7L360.927: ['Gjensidige Forsikring D', '01.12', -494.42]
# P7L350.607: ['The Writers Block Las Vegas', '01.12', -428.64]
# P7L266.607: ['Udl kortbetaling 1 50 af DKK', '01.12', -6.43]
# P7L245.487: ['GNC Æ005815 LAS VEGAS', '01.12', -156.0]
# P7L161.487: ['Udl kortbetaling 1 50 af DKK', '01.12', -2.34]
# P7L140.607: ['COCOLINI MANDALAY BAY LAS', '02.12', -37.76]
# P8L550.047: ['Udl kortbetaling 1 50 af DKK', '02.12', -0.57]
# P8L528.927: ['PAYPAL UBER 4029357733', '02.12', -90.61]
# P8L455.487: ['Udl kortbetaling 1 50 af DKK', '02.12', -1.36]
# P8L434.607: ['PAYPAL UBER 4029357733', '02.12', -90.61]
# P8L360.927: ['Udl kortbetaling 1 50 af DKK', '02.12', -1.36]
# P8L340.047: ['PAYPAL UBER 4029357733', '02.12', -75.12]
# P8L266.607: ['Udl kortbetaling 1 50 af DKK', '02.12', -1.13]
# P8L245.487: ['HGV LVBS FB LAS VEGAS', '02.12', -46.99]
# P8L161.487: ['Udl kortbetaling 1 50 af DKK', '02.12', -0.7]
# P8L140.607: ['MobilePay Caroline Boje', '02.12', -328.0]
# P8L130.047: ['MobilePay Caroline Boje', '02.12', -62.0]
# P8L119.487: ['Google CLOUD wL625x Milan', '05.12', -252.47]
# P9L528.927: ['HGV LVBS FB LAS VEGAS', '06.12', -66.84]
# P9L444.927: ['Udl kortbetaling 1 50 af DKK', '06.12', -1.0]
# P9L424.047: ['VENETIAN STARBUCKS I LAS VEGAS', '06.12', -104.68]
# P9L340.047: ['Udl kortbetaling 1 50 af DKK', '06.12', -1.57]
# P9L318.927: ['EXPO CONV CTR LAS VEGAS', '06.12', -58.78]
# P9L234.927: ['Udl kortbetaling 1 50 af DKK', '06.12', -0.88]
# P9L214.047: ['HGV LVBS FB LAS VEGAS', '06.12', -64.41]
# P9L130.047: ['Udl kortbetaling 1 50 af DKK', '06.12', -0.97]
# P9L108.927: ['SKYWALK PHOTO PEACH SPRINGS', '06.12', -69.54]
# P10L518.607: ['Udl kortbetaling 1 50 af DKK', '06.12', -1.04]
# P10L497.487: ['GCW TOUR TERMINAL PEACH SPRINGS', '06.12', -688.8]
# P10L413.487: ['Udl kortbetaling 1 50 af DKK', '06.12', -10.33]
# P10L392.607: ['MCDONALD S F24108 LAS VEGAS', '06.12', -119.4]
# P10L308.607: ['Udl kortbetaling 1 50 af DKK', '06.12', -1.79]
# P10L287.487: ['VENETIAN STARBUCKS I LAS VEGAS', '06.12', -131.46]
# P10L203.487: ['Udl kortbetaling 1 50 af DKK', '06.12', -1.97]
# P10L182.607: ['SP PSYCHO BUNNY 151 43459146', '06.12', -502.42]
# P10L98.607: ['Udl kortbetaling 1 50 af DKK', '06.12', -7.54]
# P11L570.927: ['SP KARMA LUCK 170 28681438', '06.12', -610.62]
# P11L486.927: ['Udl kortbetaling 1 50 af DKK', '06.12', -9.16]
# P11L466.047: ['BARNES NOBLE Æ2128 LAS VEGAS', '06.12', -973.6]
# P11L382.047: ['Udl kortbetaling 1 50 af DKK', '06.12', -14.6]
# P11L360.927: ['SQ SQUISHABLE COM Las Vegas', '06.12', -459.91]
# P11L276.927: ['Udl kortbetaling 1 50 af DKK', '06.12', -6.9]
# P11L256.047: ['MCDONALD S M4327 OF NV LAS VEGAS', '06.12', -171.11]
# P11L172.047: ['Udl kortbetaling 1 50 af DKK', '06.12', -2.57]
# P11L150.927: ['MACYS LAS VEGAS LAS VEGAS', '06.12', -294.65]
# P12L550.047: ['Udl kortbetaling 1 50 af DKK', '06.12', -4.42]
# P12L528.927: ['HGV LVBS FB LAS VEGAS', '06.12', -142.87]
# P12L444.927: ['Udl kortbetaling 1 50 af DKK', '06.12', -2.14]
# P12L424.047: ['BUDGET CAR AND TRUCK REN LAS', '06.12', -1165.47]
# P12L329.487: ['Udl kortbetaling 1 50 af DKK', '06.12', -17.48]
# P12L308.607: ['SuperB Solrød 62038', '06.12', -819.6]
# P12L298.047: ['BATH AND BODY WORKS 3626 LAS', '07.12', -286.02]
# P12L203.487: ['Udl kortbetaling 1 50 af DKK', '07.12', -4.29]
# P12L182.607: ['HGV LVBS FB LAS VEGAS', '07.12', -100.36]
# P12L98.607: ['Udl kortbetaling 1 50 af DKK', '07.12', -1.51]
# P13L570.927: ['PAYPAL UBER 4029357733', '07.12', -66.04]
# P13L497.487: ['Udl kortbetaling 1 50 af DKK', '07.12', -0.99]
# P13L476.607: ['ARCO Æ42395 AMPM LAS VEGAS', '07.12', -193.4]
# P13L392.607: ['Udl kortbetaling 1 50 af DKK', '07.12', -2.9]
# P13L371.487: ['CHILI S D SW LAS LAS VEGAS', '08.12', -37.02]
# P13L287.487: ['Udl kortbetaling 1 50 af DKK', '08.12', -0.56]
# P13L266.607: ['METRO PIZZA D SW LAS LAS VEGAS', '08.12', -129.6]
# P13L182.607: ['Udl kortbetaling 1 50 af DKK', '08.12', -1.94]
# P13L161.487: ['TENTATION LAS VEGAS', '08.12', -46.29]
# P14L570.927: ['Udl kortbetaling 1 50 af DKK', '08.12', -0.69]
# P14L550.047: ['SuperB Solrød 89223', '08.12', -80.95]
# P14L539.487: ['ZooBiiDoo 79426', '09.12', -219.0]
# P14L528.927: ['ezanza dk', '32482', '09.12', -795.0]
# P14L518.607: ['Depotgebyr 3033767048', '12.12', -30.18]
# P14L508.047: ['52900', 'www babysam dk', '12.12', -288.95]
# P14L497.487: ['AMZN Mktp DE 1Z43R0JW4 AMAZON DE', '13.12', -905.81]
# P14L424.047: ['Kamerahuset ApS 52178', '13.12', -298.0]
# P14L413.487: ['SAXO COM', '22107', '13.12', -10.0]
# P14L402.927: ['www grejfreak dk 23194', '13.12', -298.0]
# P14L392.607: ['64001', 'matas dk', '13.12', -279.95]
# P14L382.047: ['22107', 'SAXO COM', '13.12', -144.9]
# P14L371.487: ['BELIANI DK BAAR', '14.12', -949.0]
# P14L298.047: ['arvingen dk', '06774', '14.12', -478.0]
# P14L287.487: ['DPH Trading', 'a3096', '14.12', -1728.0]
# P14L276.927: ['Q8 Service 8042 53119', '15.12', -400.22]
# P14L266.607: ['power dk', '29779', '15.12', -1506.0]
# P14L256.047: ['McDonalds Solroed rest', '16.12', -249.0]
# P14L172.047: ['MobilePay Køge Dækcenter ApS', '19.12', -1171.25]
# P14L161.487: ['SuperB Solrød 97055', '19.12', -613.55]
# P14L150.927: ['PAYPAL ADIDASDANMA 75', '20.12', -129.0]
# P15L570.927: ['KLARNA KLARNA STOCKHOLM', '20.12', -2088.0]
# P15L497.487: ['PAYPAL SAALDIGITAL 35314369001', '20.12', -1549.0]
# P15L413.487: ['SLOTHS AUTO ApS 01668', '20.12', -861.25]
# P15L402.927: ['BAUHAUS Ishøj 97103', '20.12', -534.28]
# P15L392.607: ['Fisketorvet Føtex 38694', '22.12', -427.0]
# P15L382.047: ['Lønoverførsel', '23.12', 45708.31]
# P15L329.487: ['Boghallen Arnold B 13923', '23.12', -444.9]
# P15L318.927: ['MobilePay PostNord Danmark Online P', '26.12', -12.0]
# P15L308.607: ['H M Home 501 23657', '27.12', -272.95]
# P15L298.047: ['Fisketorvet Føtex 80078', '27.12', -980.4]
# P15L287.487: ['Magasin Kgs Nytor 54766', '27.12', -579.0]
# P15L276.927: ['AMZN Mktp DE 1N30G57X4 AMAZON DE', '28.12', -1102.17]
# P15L203.487: ['PAYPAL EASYPARK AS 35314369001', '28.12', -129.32]
# P15L119.487: ['PAYPAL ADOBESYSTEM 35314369001', '28.12', -95.19]
# P16L539.487: ['DET GAMLE APOTEK KOBENHAVN K', '28.12', -131.6]
# P16L466.047: ['McDonalds Solroed rest', '28.12', -252.0]
# P16L382.047: ['MobilePay Caroline Boje', '28.12', -319.0]
# P16L371.487: ['Elgiganten 3004 58068', '28.12', -1021.0]
# P16L360.927: ['SuperB Solrød 01936', '28.12', -667.9]
# P16L350.607: ['SuitSupply Copenhagen', '29.12', -759.0]
# P16L276.927: ['Transfer to budget', '30.12', -7300.0]
# P16L266.607: ['APPLE COM BILL ITUNES COM', '30.12', -45.0]
# P16L192.927: ['PAYPAL EASYPARK AS 35314369001', '30.12', -65.03]
# P16L108.927: ['30.12', 'MobilePay Caroline Boje', -599.75]
